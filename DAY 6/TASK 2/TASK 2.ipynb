# %%
{
  "match": "Rajasthan Royals vs Gujarat Titans",
  "format": "Final",
  "innings": [
    {
      "team": "Gujarat Titans",
      "overs": [
        {
          "over": 17,
          "balls": [
            {
              "ball": 16.1,
              "bowler": "Prasidh Krishna",
              "batsman": "Miller",
              "runs": 2,
              "description": "Length ball on the stumps, flicked towards deep square leg."
            },
            {
              "ball": 16.2,
              "bowler": "Prasidh Krishna",
              "batsman": "Miller",
              "runs": 2,
              "description": "Short of length outside off, cuts it behind point."
            },
            {
              "ball": 16.3,
              "bowler": "Prasidh Krishna",
              "batsman": "Miller",
              "runs": 0,
              "description": "Length ball angling across, misses the cut."
            },
            {
              "ball": 16.4,
              "bowler": "Prasidh Krishna",
              "batsman": "Miller",
              "runs": 4,
              "description": "Short ball on the stumps, top-edged pull goes fine for four."
            },
            {
              "ball": 16.5,
              "bowler": "Prasidh Krishna",
              "batsman": "Miller",
              "runs": 1,
              "extras": "wide",
              "description": "Short and too high, called wide."
            },
            {
              "ball": 16.5,
              "bowler": "Prasidh Krishna",
              "batsman": "Miller",
              "runs": 4,
              "description": "Short outside off, thick edge past third man."
            },
            {
              "ball": 16.6,
              "bowler": "Prasidh Krishna",
              "batsman": "Miller",
              "runs": 2,
              "description": "Length ball on the stumps, flicked to deep square leg."
            }
          ]
        },
        {
          "over": 18,
          "balls": [
            {
              "ball": 17.1,
              "bowler": "Ashwin",
              "batsman": "Gill",
              "runs": 0,
              "description": "Length ball around off, reverse hit to cover."
            },
            {
              "ball": 17.2,
              "bowler": "Ashwin",
              "batsman": "Gill",
              "runs": 1,
              "description": "Length ball spinning in, worked to midwicket."
            },
            {
              "ball": 17.3,
              "bowler": "Ashwin",
              "batsman": "Miller",
              "runs": 1,
              "description": "Carrom ball, punched to sweeper cover."
            },
            {
              "ball": 17.4,
              "bowler": "Ashwin",
              "batsman": "Gill",
              "runs": 0,
              "description": "Length ball on middle, flicked to square leg."
            },
            {
              "ball": 17.5,
              "bowler": "Ashwin",
              "batsman": "Gill",
              "runs": 1,
              "description": "Slower and wider, cut to deep point."
            },
            {
              "ball": 17.6,
              "bowler": "Ashwin",
              "batsman": "Miller",
              "runs": 2,
              "description": "Length ball, inside edge past stumps to fine leg."
            }
          ]
        }
      ]
    }
  ]
}
# Out:
# {'match': 'Rajasthan Royals vs Gujarat Titans',
#  'format': 'Final',
#  'innings': [{'team': 'Gujarat Titans',
#    'overs': [{'over': 17,
#      'balls': [{'ball': 16.1,
#        'bowler': 'Prasidh Krishna',
#        'batsman': 'Miller',
#        'runs': 2,
#        'description': 'Length ball on the stumps, flicked towards deep square leg.'},
#       {'ball': 16.2,
#        'bowler': 'Prasidh Krishna',
#        'batsman': 'Miller',
#        'runs': 2,
#        'description': 'Short of length outside off, cuts it behind point.'},
#       {'ball': 16.3,
#        'bowler': 'Prasidh Krishna',
#        'batsman': 'Miller',
#        'runs': 0,
#        'description': 'Length ball angling across, misses the cut.'},
#       {'ball': 16.4,
#        'bowler': 'Prasidh Krishna',
#        'batsman': 'Miller',
#        'runs': 4,
#        'description': 'Short ball on the stumps, top-edged pull goes fine for four.'},
#       {'ball': 16.5,
#        'bowler': 'Prasidh Krishna',
# ...
